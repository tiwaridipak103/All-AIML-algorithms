# %% [markdown]
# ![image.png](attachment:1298caff-af63-41ba-b843-ff0188c1049e.png)
# ![image.png](attachment:cc222c36-6695-4569-84ba-138f716d0ab5.png)
# ![image.png](attachment:a1ad1a30-be44-43ea-b8eb-83468034f6c3.png)
# ![image.png](attachment:3fe3d4be-5517-44d9-9f79-6d05a6e43e65.png)

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Generate some sample data
np.random.seed(0)
n = 100  # Number of observations
p = 3    # Number of predictors (including intercept)

X = np.random.randn(n, p)  # Random predictors
beta = np.array([1, 2, 3])  # True coefficients
epsilon = np.random.randn(n)  # Error term
y = X.dot(beta) + epsilon  # True relationship plus noise

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Calculate R-squared
r_squared = model.score(X, y)
print(f"R-squared: {r_squared}")

# Calculate adjusted R-squared
k = p  # Number of predictors (including intercept)
n = len(y)  # Number of observations

adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - k - 1)
print(f"Adjusted R-squared: {adjusted_r_squared}")
# Out:
# R-squared: 0.9404355259543044
# Adjusted R-squared: 0.9385741361403763
